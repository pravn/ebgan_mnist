# %%
import numpy
import torch
import torch.utils.data
from torchvision import datasets, transforms

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class Params:
    def __init__(self):
        self.batch_size = 32
        self.num_batches = -1
        self.num_samples = -1
        self.n_z = 256
        self.dim_h = 50
        self.sigma = 1
        self.LAMBDA = 10
        self.margin = 40
        self.lr = 1.*1e-4
        self.Diters = 5
        self.n_channel = 1
        self.x_size = 28
        self.y_size = 28
params = Params()

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=params.batch_size, shuffle=True)
params.num_batches = len(train_loader)
params.num_samples = params.num_batches * params.batch_size

# %%
# %aimport ebgan
from ebgan import return_model
decoder, disc = return_model(params)
# Out:
# return model - decoder.cuda(), disc.cuda()

# %%
# %aimport train_ebgan
from train_ebgan import run_trainer

# %%
run_trainer(train_loader, disc, decoder, params)
# Out:
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 1 154887.4151061196 14788.686448931694
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 2 128028.54392051697 12449.156138658524
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 3 131378.98387527466 11629.836590051651
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 4 118941.49223709106 12452.376492738724
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 5 112549.98685073853 13864.191588282585
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 6 108083.3564710617 14832.851952195168
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 7 109293.05193138123 13875.223179578781
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 8 104833.64210605621 14233.452352523804
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 9 106054.03644371033 13344.239702939987
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 10 106106.45058441162 12515.999017477036
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 11 108919.654794693 11559.023663043976
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 12 112498.3082447052 10752.541603207588
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 13 118445.16010475159 8763.222143888474
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 14 123060.52633476257 6550.278462648392
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 15 131218.53913497925 5634.411029517651
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 16 140839.91206741333 5034.213944554329
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 17 142958.4475440979 4280.927608311176
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 18 146428.01922988892 4074.8194437921047
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 19 146513.33400726318 3736.988222807646
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 20 149900.17670059204 3711.9918551445007
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 21 151644.67831993103 3432.7611412107944
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 22 150742.28872299194 3271.802823960781
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 23 151721.5818195343 3425.355064958334
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 24 151603.30577468872 3242.498998492956
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 25 154493.77398109436 3275.499042093754
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 26 156483.09623718262 3122.802485316992
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 27 157535.71717453003 3314.090848863125
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 28 156804.50745010376 3109.3140800595284
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 29 156745.88092041016 3136.6546901762486
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 30 154841.33720588684 3223.1251318454742
# saving images for batch 0
# saving images for batch 200
# saving images for batch 400
# saving images for batch 600
# saving images for batch 800
# saving images for batch 1000
# saving images for batch 1200
# saving images for batch 1400
# saving images for batch 1600
# saving images for batch 1800
# Epoch, G_loss, D_loss 31 159182.95900917053 3190.171175569296
# saving images for batch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1d0ef28b0f4c> in <module>()
# ----> 1 run_trainer(train_loader, disc, decoder, params)
#
# /home/pytorch/projects/ebgan_mnist/train_ebgan.py in run_trainer(train_loader, netD, netG, args)
#     107
#     108
# --> 109             errD_fake.backward()
#     110
#     111             errD = (errD_real + errD_fake)/2.0
#
# /home/pytorch/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# /home/pytorch/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:
